# %% [markdown]
# Nous allons ici réaliser l'ensemble des étapes de préprocessing et d'analyse exploratoire de nos données nécessaires avant l'implémentation d'un modèle de Machine Learning. Le but ici est d'explorer l'ensemble de ces étapes séparemment ce qui nous permettra de voir chacune leur spécificité.

# %%
import pandas as pd 
import numpy as np

# %%
# Chargement de nos données CSV
data = pd.read_csv('marketing_campaign.csv', sep=';')

# %%
# Affichage des 10 premières lignes 
data.head(10)
# Out:
#      ID  Year_Birth   Education  ... Z_CostContact  Z_Revenue  Response
# 0  5524        1957  Graduation  ...             3         11         1
# 1  2174        1954  Graduation  ...             3         11         0
# 2  4141        1965  Graduation  ...             3         11         0
# 3  6182        1984  Graduation  ...             3         11         0
# 4  5324        1981         PhD  ...             3         11         0
# 5  7446        1967      Master  ...             3         11         0
# 6   965        1971  Graduation  ...             3         11         0
# 7  6177        1985         PhD  ...             3         11         0
# 8  4855        1974         PhD  ...             3         11         1
# 9  5899        1950         PhD  ...             3         11         0
#
# [10 rows x 29 columns]

# %%
# Nombre de lignes et colonnes du dataset
data.shape
# Out:
# (2240, 29)

# %%
# Type de variables dans notre jeu de données 
data.dtypes
# Out:
# ID                       int64
# Year_Birth               int64
# Education               object
# Marital_Status          object
# Income                 float64
# Kidhome                  int64
# Teenhome                 int64
# Dt_Customer             object
# Recency                  int64
# MntWines                 int64
# MntFruits                int64
# MntMeatProducts          int64
# MntFishProducts          int64
# MntSweetProducts         int64
# MntGoldProds             int64
# NumDealsPurchases        int64
# NumWebPurchases          int64
# NumCatalogPurchases      int64
# NumStorePurchases        int64
# NumWebVisitsMonth        int64
# AcceptedCmp3             int64
# AcceptedCmp4             int64
# AcceptedCmp5             int64
# AcceptedCmp1             int64
# AcceptedCmp2             int64
# Complain                 int64
# Z_CostContact            int64
# Z_Revenue                int64
# Response                 int64
# dtype: object

# %%
# On souhaite changer le format de la colonne Dt_Customer pour le mettre en data 
data['Dt_Customer'] = pd.to_datetime(data['Dt_Customer'], format='%Y-%m-%d')

# %%
# Identification des colonnes où il y'a des vides 
data.isna().sum()
# Out:
# ID                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
# Income                 24
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# AcceptedCmp3            0
# AcceptedCmp4            0
# AcceptedCmp5            0
# AcceptedCmp1            0
# AcceptedCmp2            0
# Complain                0
# Z_CostContact           0
# Z_Revenue               0
# Response                0
# dtype: int64

# %%
# Repérer le nombre de doublons dans notre jeu de données 
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Infos générales sur notre dataset 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   datetime64[ns]
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
# Ici nous avons seulement une colonne avec 24 lignes vides soit environ 1% de données manquantes dans notre dataset. On peut donc supprimer simplement tous les vides du dataset sans perdre un grand nombre d'information pour une éventuel implémentation de Machine Learning.

data_clean = data.dropna()
data_clean.isna().sum()
# Out:
# ID                     0
# Year_Birth             0
# Education              0
# Marital_Status         0
# Income                 0
# Kidhome                0
# Teenhome               0
# Dt_Customer            0
# Recency                0
# MntWines               0
# MntFruits              0
# MntMeatProducts        0
# MntFishProducts        0
# MntSweetProducts       0
# MntGoldProds           0
# NumDealsPurchases      0
# NumWebPurchases        0
# NumCatalogPurchases    0
# NumStorePurchases      0
# NumWebVisitsMonth      0
# AcceptedCmp3           0
# AcceptedCmp4           0
# AcceptedCmp5           0
# AcceptedCmp1           0
# AcceptedCmp2           0
# Complain               0
# Z_CostContact          0
# Z_Revenue              0
# Response               0
# dtype: int64

# %%
cat_vars = list(data.select_dtypes(include=['object']))

# Encodage des variables catégorielles 
data_encoded = pd.get_dummies(data, columns=cat_vars, drop_first=True)
data_encoded.head()
# Out:
#      ID  Year_Birth  ...  Marital_Status_Widow  Marital_Status_YOLO
# 0  5524        1957  ...                 False                False
# 1  2174        1954  ...                 False                False
# 2  4141        1965  ...                 False                False
# 3  6182        1984  ...                 False                False
# 4  5324        1981  ...                 False                False
#
# [5 rows x 38 columns]

# %% [markdown]
# Analyse univariée

# %%
# Détecter les outliers dans un dataset avec la méthode de l'interquartile

num_vars = list(data.select_dtypes(include=['int64','float64']))

def outliers(df,col):
    df = df.copy()
    q1 = data[col].quantile(0.25)
    q3 = data[col].quantile(0.75)
    IQR = q3 - q1
    lower_bound = q1 - 1.5 * IQR
    upper_bound = q3 + 1.5 * IQR
    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
    return outliers

print(outliers(data,num_vars))
# Out:
#       ID  Year_Birth Education  ... Z_CostContact  Z_Revenue  Response
# 0    NaN         NaN       NaN  ...           NaN        NaN       1.0
# 1    NaN         NaN       NaN  ...           NaN        NaN       NaN
# 2    NaN         NaN       NaN  ...           NaN        NaN       NaN
# 3    NaN         NaN       NaN  ...           NaN        NaN       NaN
# 4    NaN         NaN       NaN  ...           NaN        NaN       NaN
# ...   ..         ...       ...  ...           ...        ...       ...
# 2235 NaN         NaN       NaN  ...           NaN        NaN       NaN
# 2236 NaN         NaN       NaN  ...           NaN        NaN       NaN
# 2237 NaN         NaN       NaN  ...           NaN        NaN       NaN
# 2238 NaN         NaN       NaN  ...           NaN        NaN       NaN
# 2239 NaN         NaN       NaN  ...           NaN        NaN       1.0
#
# [2240 rows x 29 columns]

# %%
# Détecter les outliers dans un dataset avec un Boxplot 
import seaborn as sns
import matplotlib.pyplot as plt

# Ici on prend une des colonnes numériques de notre dataset 
sns.boxplot(x=data['MntMeatProducts'])
plt.show()

# %%
# On veut gérer les outliers pour les mettres sur les bornes supérieurs/inférieurs 

# Fonction pour "caper" les outliers aux bornes inférieure et supérieure

def cap_outliers(data, column):
    df = data.copy()
    for col in column: 
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower = Q1 - 1.5 * IQR
        upper = Q3 + 1.5 * IQR
        df[col] = np.where(df[col] < lower,lower, np.where(df[col] > upper, upper, df[col]))
    return df

# Application
data_capped = cap_outliers(data, num_vars)
data_capped
# Out:
#            ID  Year_Birth   Education  ... Z_CostContact  Z_Revenue  Response
# 0      5524.0      1957.0  Graduation  ...           3.0       11.0       0.0
# 1      2174.0      1954.0  Graduation  ...           3.0       11.0       0.0
# 2      4141.0      1965.0  Graduation  ...           3.0       11.0       0.0
# 3      6182.0      1984.0  Graduation  ...           3.0       11.0       0.0
# 4      5324.0      1981.0         PhD  ...           3.0       11.0       0.0
# ...       ...         ...         ...  ...           ...        ...       ...
# 2235  10870.0      1967.0  Graduation  ...           3.0       11.0       0.0
# 2236   4001.0      1946.0         PhD  ...           3.0       11.0       0.0
# 2237   7270.0      1981.0  Graduation  ...           3.0       11.0       0.0
# 2238   8235.0      1956.0      Master  ...           3.0       11.0       0.0
# 2239   9405.0      1954.0         PhD  ...           3.0       11.0       0.0
#
# [2240 rows x 29 columns]

# %%
# Eléments descriptifs des colonnes numériques de notre dataset 
data.describe()
# Out:
#                  ID   Year_Birth  ...  Z_Revenue     Response
# count   2240.000000  2240.000000  ...     2240.0  2240.000000
# mean    5592.159821  1968.805804  ...       11.0     0.149107
# min        0.000000  1893.000000  ...       11.0     0.000000
# 25%     2828.250000  1959.000000  ...       11.0     0.000000
# 50%     5458.500000  1970.000000  ...       11.0     0.000000
# 75%     8427.750000  1977.000000  ...       11.0     0.000000
# max    11191.000000  1996.000000  ...       11.0     1.000000
# std     3246.662198    11.984069  ...        0.0     0.356274
#
# [8 rows x 27 columns]

# %%
# Regarder la distribution des colonnes numériques par l'histogramme 
# On va prendre arbitrairement 3 colonnes numériques 
data['Response'].hist()
plt.show()

# %%
data['Kidhome'].hist()
plt.show()

# %%
data['NumWebVisitsMonth'].hist()
plt.show()

# %%
# Composition des variables catégorielles 
data['Education'].value_counts()
# Out:
# Education
# Graduation    1127
# PhD            486
# Master         370
# 2n Cycle       203
# Basic           54
# Name: count, dtype: int64

# %%
data['Marital_Status'].value_counts()
# Out:
# Marital_Status
# Married     864
# Together    580
# Single      480
# Divorced    232
# Widow        77
# Alone         3
# Absurd        2
# YOLO          2
# Name: count, dtype: int64

# %%
data['Year_Birth'].value_counts()
# Out:
# Year_Birth
# 1976    89
# 1971    87
# 1975    83
# 1972    79
# 1978    77
# 1970    77
# 1973    74
# 1965    74
# 1969    71
# 1974    69
# 1956    55
# 1958    53
# 1979    53
# 1952    52
# 1977    52
# 1968    51
# 1959    51
# 1966    50
# 1954    50
# 1955    49
# 1960    49
# 1982    45
# 1963    45
# 1967    44
# 1962    44
# 1957    43
# 1951    43
# 1983    42
# 1986    42
# 1964    42
# 1980    39
# 1981    39
# 1984    38
# 1961    36
# 1953    35
# 1985    32
# 1989    30
# 1949    30
# 1950    29
# 1988    29
# 1987    27
# 1948    21
# 1990    18
# 1946    16
# 1947    16
# 1991    15
# 1992    13
# 1945     8
# 1943     7
# 1944     7
# 1993     5
# 1995     5
# 1994     3
# 1996     2
# 1899     1
# 1941     1
# 1893     1
# 1900     1
# 1940     1
# Name: count, dtype: int64

# %% [markdown]
# Analyse bivariée et multivariée

# %%
# Vérification d'une potentiel relation linéaire entre nos variables numériques

data_num = data[num_vars]
data_num.dropna()
data_num.drop('Response',axis=1, inplace=True) # Suppression de la variable cible 
corr_pearson = data_num.corr(method='pearson')
print("Corrélation de Pearson :\n", corr_pearson)
# Out:
# Corrélation de Pearson :
#                             ID  Year_Birth  ...  Z_CostContact  Z_Revenue
# ID                   1.000000    0.000028  ...            NaN        NaN
# Year_Birth           0.000028    1.000000  ...            NaN        NaN
# Income               0.013095   -0.161791  ...            NaN        NaN
# Kidhome              0.002406    0.230176  ...            NaN        NaN
# Teenhome            -0.002580   -0.352111  ...            NaN        NaN
# Recency             -0.046524   -0.019871  ...            NaN        NaN
# MntWines            -0.022878   -0.157773  ...            NaN        NaN
# MntFruits            0.004600   -0.017917  ...            NaN        NaN
# MntMeatProducts     -0.004437   -0.030872  ...            NaN        NaN
# MntFishProducts     -0.024475   -0.041625  ...            NaN        NaN
# MntSweetProducts    -0.007642   -0.018133  ...            NaN        NaN
# ...

# %%
# On affiche une matrice de corrélation 
# Pour voir la correlation entre nos variables numériques
# Il faut une certaine indépendance entre les variables pour notre modèle 

corr = data_num.corr()
plt.figure(figsize=(18, 6))
sns.heatmap(data = corr, vmin=-1, vmax=1, annot=True)
# Out:
# <Axes: >
